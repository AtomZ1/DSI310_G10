# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 125
dir_process_id = 126

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY2OTUwMzQ1LCJpYXQiOjE2NjY2Nzk3NzIsImp0aSI6IjRlN2JjYTNjZjE4ODQ1NzM5ODNkMzk2OTM2ODliZTQxIiwidXNlcl9pZCI6MTh9.58YltQtkZhivDWoEF13Fh70QNI4hZqdKwukRQPC74rU"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='news.json'))
meta
# Out:
# {'owner': 'konthorn',
#  'human_size': '2.27 KB',
#  'name': 'news.json',
#  'description': 'file news.json',
#  'directory': 125,
#  'path': 'konthorn/DSI310-10/rawData/news.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'name': '& Other Stories X A.W.A.K.E Mode Has Just Dropped: Here’s The Vogue Verdict\xa0',
#   'grouping': 'VOGUE SHOPS',
#   'author': 'Joy Montgomery',
#   'time': '27 October 2022'},
#  {'name': 'Victoria Beckham And Mia Regan Give ',
#   'grouping': 'Fashion',
#   'author': 'Alice Cary',
#   'time': '27 October 2022'},
#  {'name': 'Bottega’s Kalimero Is More Objet Than It-Bag And Already Beloved',
#   'grouping': 'fashion',
#   'author': 'Alice Newbold',
#   'time': '26 October 2022'},
#  {'name': 'The Roomy Moto Jacket Is Taking Over This Autumn',
#   'grouping': 'Fashion Trends',
#   'author': 'Christian Allaire',
#   'time': '26 October 2022'},
#  {'name': 'Christmas Gift Ideas For Absolutely Everyone On Your List – All In One Place',
#   'grouping': 'Christmas Gift Guides',
#   'author': 'Humaa Hussain',
#   'time': '26 October 2022'},
#  {'name': 'Kaia Gerber’s Understated Take On Supermodel Style Never Fails To Deliver',
#   'grouping': 'Fashion',
# ...

# %%
data = pd.read_json('news.json')
data
# Out:
#                                                  name               grouping  \
# 0   & Other Stories X A.W.A.K.E Mode Has Just Drop...            VOGUE SHOPS
# 1                Victoria Beckham And Mia Regan Give                 Fashion
# 2   Bottega’s Kalimero Is More Objet Than It-Bag A...                fashion
# 3    The Roomy Moto Jacket Is Taking Over This Autumn         Fashion Trends
# 4   Christmas Gift Ideas For Absolutely Everyone O...  Christmas Gift Guides
# 5   Kaia Gerber’s Understated Take On Supermodel S...                Fashion
# 6       6 Expert Tips For Looking After Your Knitwear        Sustainability
# 7                                          Contact Us               In Vogue
# 8   Instead Of A Dress, Consider A Matching Skirt-...                Fashion
# 9            Kitten Heels Are Back – Really This Time         Fashion Trends
# 10  Every Day’s A Duvet Day With These Cosy Puffer...                Fashion
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                  name               grouping  \
# 0   & Other Stories X A.W.A.K.E Mode Has Just Drop...            VOGUE SHOPS
# 1                Victoria Beckham And Mia Regan Give                 Fashion
# 2   Bottega’s Kalimero Is More Objet Than It-Bag A...                fashion
# 3    The Roomy Moto Jacket Is Taking Over This Autumn         Fashion Trends
# 4   Christmas Gift Ideas For Absolutely Everyone O...  Christmas Gift Guides
# 5   Kaia Gerber’s Understated Take On Supermodel S...                Fashion
# 6       6 Expert Tips For Looking After Your Knitwear        Sustainability
# 7                                          Contact Us               In Vogue
# 8   Instead Of A Dress, Consider A Matching Skirt-...                Fashion
# 9            Kitten Heels Are Back – Really This Time         Fashion Trends
# 10  Every Day’s A Duvet Day With These Cosy Puffer...                Fashion
# ...

# %%
df = df.rename(columns = {'name' : 'Title'})
df = df.rename(columns = {'grouping' : 'Category'})
df = df.rename(columns = {'author' : 'Author'})
df = df.rename(columns = {'time' : 'Date'})
df
# Out:
#                                                 Title               Category  \
# 0   & Other Stories X A.W.A.K.E Mode Has Just Drop...            VOGUE SHOPS
# 1                Victoria Beckham And Mia Regan Give                 Fashion
# 2   Bottega’s Kalimero Is More Objet Than It-Bag A...                fashion
# 3    The Roomy Moto Jacket Is Taking Over This Autumn         Fashion Trends
# 4   Christmas Gift Ideas For Absolutely Everyone O...  Christmas Gift Guides
# 5   Kaia Gerber’s Understated Take On Supermodel S...                Fashion
# 6       6 Expert Tips For Looking After Your Knitwear        Sustainability
# 7                                          Contact Us               In Vogue
# 8   Instead Of A Dress, Consider A Matching Skirt-...                Fashion
# 9            Kitten Heels Are Back – Really This Time         Fashion Trends
# 10  Every Day’s A Duvet Day With These Cosy Puffer...                Fashion
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="Vogue : Category magazine ", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='news.json')])
# Out:
# {'sucess': True,
#  'file_id': 275,
#  'path': 'konthorn/DSI310-10/processData/Vogue : Category magazine .parquet',
#  'lineage': True}
