# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 125
dir_process_id = 126

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY5MjIyNzU1LCJpYXQiOjE2NjkwMjc2MDgsImp0aSI6IjYyZDdiODBlN2Y1YjRkZjA4MGRhZTBiZjkxOWYzMjMzIiwidXNlcl9pZCI6MTh9.DG89V2547S_L0BGUHTR9ab7cDxIyFUpxEB274DbS6HA"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='wwd.json'))
meta
# Out:
# {'owner': 'konthorn',
#  'human_size': '4.11 KB',
#  'name': 'wwd.json',
#  'description': 'file wwd.json',
#  'directory': 125,
#  'path': 'konthorn/DSI310-10/rawData/wwd.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'title': 'EXCLUSIVE: Maison Mazerea Debuts Yellow Diamond Jewelry Collection',
#   'urls': 'https://wwd.com/accessories-news/',
#   'published_datetime': '2019-09-03',
#   'content': '"My bias is toward the beauty of the diamond, the jewelry is the supporting act," said founder Peter J…'},
#  {'title': 'Tiffany & Co. Brings New Approach to Holiday Season With 360-Degree Campaign Inspired by Andy Warhol',
#   'urls': 'https://wwd.com/accessories-news/',
#   'published_datetime': '2019-09-03',
#   'content': 'Tiffany is establishing visual continuity across store displays, advertising and product for the…'},
#  {'title': 'Lupita Nyong’o Joins De Beers as Its First Global Ambassador',
#   'urls': 'https://wwd.com/accessories-news/',
#   'published_datetime': '2019-09-03',
#   'content': 'The Academy Award winner appears in the brand\'s "Where It Begins," campaign photographed by Lachlan Bailey.'},
# ...

# %%
data = pd.read_json('wwd.json')
data
# Out:
#                                                 title  \
# 0   The Future Rocks, a Marketplace Betting on Lab...
# 1   Taking the Temperature of a Growing Jewelry Ma...
# 2            Hidden Gems: Key Jewelry Moments in Film
# 3   Meet the Fine Jewelry Brand Named After a 12th...
# 4   Paris-based Jeweler Viltier Sets Off on Americ...
# 5                                     What Is Mociun?
# 6       Why Own a Diamond Ring When You Can Rent One?
# 7   Golden Eye: Missoma’s Marisa Hordern Looks to ...
# 8   ‘Bridgerton’ and Monica Rich Kosann Bring the ...
# 9     TenThousandThings Celebrates 30 Years of Design
# 10                  Leviev Unveils Empresses Diamonds
# 11  Susan Alexandra Lights Up the Holidays With Ju...
# 12  Tiffany & Co. Deepens HBCU Support in Partners...
# 13             Muse Partners With Every Mother Counts
# 14          Karma El Khalil Lands at Bergdorf Goodman
#
#                                  urls published_datetime  \
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                 title  \
# 0   The Future Rocks, a Marketplace Betting on Lab...
# 1   Taking the Temperature of a Growing Jewelry Ma...
# 2            Hidden Gems: Key Jewelry Moments in Film
# 3   Meet the Fine Jewelry Brand Named After a 12th...
# 4   Paris-based Jeweler Viltier Sets Off on Americ...
# 5                                     What Is Mociun?
# 6       Why Own a Diamond Ring When You Can Rent One?
# 7   Golden Eye: Missoma’s Marisa Hordern Looks to ...
# 8   ‘Bridgerton’ and Monica Rich Kosann Bring the ...
# 9     TenThousandThings Celebrates 30 Years of Design
# 10                  Leviev Unveils Empresses Diamonds
# 11  Susan Alexandra Lights Up the Holidays With Ju...
# 12  Tiffany & Co. Deepens HBCU Support in Partners...
# 13             Muse Partners With Every Mother Counts
# 14          Karma El Khalil Lands at Bergdorf Goodman
#
#                                  urls published_datetime  \
# ...

# %%
df = df.rename(columns = {'title' : 'Title'})
df = df.rename(columns = {'urls' : 'Urls'})
df = df.rename(columns = {'published_datetime' : 'Date'})
df = df.rename(columns = {'content' : 'Content'})
df
# Out:
#                                                 Title  \
# 0   The Future Rocks, a Marketplace Betting on Lab...
# 1   Taking the Temperature of a Growing Jewelry Ma...
# 2            Hidden Gems: Key Jewelry Moments in Film
# 3   Meet the Fine Jewelry Brand Named After a 12th...
# 4   Paris-based Jeweler Viltier Sets Off on Americ...
# 5                                     What Is Mociun?
# 6       Why Own a Diamond Ring When You Can Rent One?
# 7   Golden Eye: Missoma’s Marisa Hordern Looks to ...
# 8   ‘Bridgerton’ and Monica Rich Kosann Bring the ...
# 9     TenThousandThings Celebrates 30 Years of Design
# 10                  Leviev Unveils Empresses Diamonds
# 11  Susan Alexandra Lights Up the Holidays With Ju...
# 12  Tiffany & Co. Deepens HBCU Support in Partners...
# 13             Muse Partners With Every Mother Counts
# 14          Karma El Khalil Lands at Bergdorf Goodman
#
#                                  Urls        Date  \
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="wwd", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='wwd.json')])
# Out:
# {'sucess': True,
#  'file_id': 1012,
#  'path': 'konthorn/DSI310-10/processData/wwd.parquet',
#  'lineage': True}
